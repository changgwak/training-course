# %% [markdown]
# # 머신러닝 오리엔테이션

# %% [markdown]
# ## 머신러닝의 정의 및 범위
# <img src="./image/01.png">
#
# 출처 : https://www.deeplearningbook.org/contents/intro.html

# %% [markdown]
# ### 머신러닝 이전의 데이터 분석 혹은 모델링과의 차이
# > 기존 모델링
# >> **사람이 알고리즘 설계 및 코딩**
# **전문가 혹은 도메인 지식을 바탕**으로 한 조건에 따른 작업 지시 혹은 결과 도출(모델링)
# **사람의 주관**이 많이 개입 된 모델링, 경험적 모델링
#
# > 머신러닝 모델링
# >> 사람이 코딩을 하는 것은 같음
# **머신러닝 알고리즘에 따라 데이터를 학습하고 그에 따라 컴퓨터가 모델링**
# **데이터 기반의 모델학습**에 따른 모델링, 데이터 모델링
#
# 즉 기존 방법은 경험적으로 학습한 전문가에 의한 모델링이 이루어졌다면 머신러닝 모델링은 데이터를 학습한 알고리즘으로서 모델링을 합니다.

# %% [markdown]
# ### 용어정리
# 머신러닝은 태생적으로 여러 분야가 결합된 분야이기 때문에 실무자들은 종종 동일한 의미에 대해 다양한 용어들을 사용합니다.
# 혼용하는 용어를 정리해보겠습니다.
# > **알고리즘(algorithm)** : 모델, 함수, 혹은 머신러닝 기법을 실행하기 위한 특정 절차
# > **샘플(sample)** : 데이터의 기본 단위. 하나의 사건 혹은 시점. 레코드, 인스턴스, 관측치, row data로 부름
# > **변수(feature)** : 입력값으로 사용되는 변수, 입력변수, 독립변수, X라고도 부름
# > **레이블(label)** : 한 샘플에 대한 정답 값. 클래스, 타겟데이터, 종속변수, 반응변수, y라고 부름

# %% [markdown]
# ### 머신러닝의 기본컨셉
#
# # $$y = f(x)$$
#
# * $y$ = 해결해야 하는 문제 (종속변수, target data)
# * $f()$ = 머신러닝 알고리즘 (모델)
# * $x$ = 훈련데이터 (설명변수, train data)
#
# ###### 머신러닝 프로젝트는 결국 $y$를 어떻게 풀어낼 것인가에 대한 기획

# %% [markdown]
# ## 머신러닝의 구분
# **$y$** 데이터의 존재 유무에 따라 **supervised learning**과 **unsupervised learning**으로 구분하며
# 각각의 학습방법 내 **$y$** 데이터의 종류에 따라 **prediction**, **classification** 문제로 구분합니다.
#
# ### supervised learning -  $y$값이 존재
# - 모델이 prediction/classification를 하기 위한 정답/target값 까지 함께 학습하는 머신러닝 모델
# - 정답(label)값이 반드시 필요
#
# #### 해결 가능한 $y$ 값의 데이터에 따른 분류
#
# ##### **prediction** : 종속변수가 **연속형** 데이터
# > * 연속형 데이터 - 매출, 온도, 시간, 코스피지수, 가격 등
# > * 자연수 0과 1사이에는 무수히 많은 실수가 존재하고 그 무한한 값의 범위를 갖는 데이터를 연속형 데이터라 한다.
# >
# <img src="./image/02.png">
#
#
# ##### **classification** : 종속변수가 **범주형** 데이터
# > * 범주형 데이터 - 성별, 신용등급, 브랜드, 기차역등
# > * 남성 혹은 여성 구분처럼 이진형 구분(0 혹은 1), 데이터가 특정 범위내에 모두 속한 데이터의 경우 범주형 데이터 혹은 카테고리 데이터라고 한다.
# >
# <img src="./image/03.png">
#
# ###### 정답을 주고 컴퓨터가 이 정답을 맞출 수 있도록 학습, 객관적 평가 가능
# ###### 지도학습은 무조건 과거 정답 데이터가 있어야 합니다.

# %% [markdown]
# ### unsupervised learning
# 모델이 학습을 하기위한 정답값이 없는 경우 활용가능한 머신러닝 모델
# clustering, recommended system에 활용 가능
#
# #### 해결 가능한 $y$ 값의 데이터에 따른 분류
#
# ##### **clustering** : 모델 결과값이  **범주형** 데이터
# > * 정답이 없는 데이터를 모델에 따라 비슷한 샘플끼리 묶어주는 머신러닝 알고리즘
# > * 데이터에 숨겨진 특징이나 구조를 발견하여 같은 특징에 따라 구분
# >
# <img src="./image/04.png">
#
# ##### **association rule analysis** : 모델 결과값이 스코어 혹은 샘플
# > * 보통 recommended system이라 부르며 매출 및 유저의 구매기록에 기반한 규칙을 찾는 알고리즘
# > * 아이템 혹은 유저를 기준으로 비슷한 아이템 및 유저를 찾아 비슷한 데이터를 찾음.
# >
# <img src="./image/05.png">
#
# ###### 평가에 필요한 과거 정답데이터가 없기에 객관적 평가 불가능

# %% [markdown]
# <small>이미지출처 : https://snowdeer.github.io/machine-learning/2016/09/03/machine-learning-algorithms/</small>
# <small>https://www.kdnuggets.com/2016/04/association-rules-apriori-algorithm-tutorial.html</small>

# %% [markdown]
# ### 문제정의
# 데이터를 기반으로 한 모델링으로 어떠한 문제를 해결해야 할지 정의하는 단계
# 올바른 문제정의가 된다면 이후 프로세스를 진행하기 수월해집니다.
# 통계적 배경지식이 중요(업무 base)
#
# 문제정의 예시
# > 1. 불량제품 분류 모델
# 종속변수 : 제품불량 (OK or NG)
# 설명변수 : 공정데이터 각 공정별 설비 로그 및 측정 가능한 데이터
# 모델 : 정답데이터가 있는 경우 classification 모델, 혹은 clustering
#
# > 2. 3/4 메모리 반도체 수요 예측
# 종속변수 : 메모리 반도체 수요
# 설명변수 : 반도체 가격, 타사 생산량, 환율, 스마트폰 판매량, 서버 판매량, 원자재 지수 등
# 모델 : 예측문제를 해결하기 위한 regression 모델

# %% [markdown]
# ## 파이썬 머신러닝 패키지 scikit-learn
# > 머신러닝 모델링을 위한 파이썬 오픈소스 패키지
# > 다양한 머신러닝 모델뿐 아니라 머신러닝 모델링을 위한 전처리 알고리즘, 평가지표, 운영 방법론을 제공한다.
#
# >> [https://scikit-learn.org/stable](https://scikit-learn.org/stable/)

# %% [markdown]
# ## 지도학습 머신러닝 데이터 플로우 프로세스
# ### 데이터셋 제작 및 확보
# <img src="./image/06.png" height="300px" width="300px">

# %%
# !pip install pandas
# Out:
# 'pip'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 필요모듈 import 
import pandas as pd

# %%
# 분석 프로세스 예시를 위해 보스턴 주택가격 예측 데이터셋을 사용하겠습니다.
# 보스턴 주택가격 예측을 위한 데이터로서 13개의 설명변수(X) 와 보스턴 집값(y)로 구성되어 있는 데이터셋입니다.
# 설명변수의 설명은 아래와 같습니다.
# 보스턴 집값 데이터 로딩

'''
각 데이터별 설명
- CRIM : 마을당 범죄율
- ZN : 25,000 평방피트 이상의 부지에 대한 주거용지 비율
- INDUS : 마을당 상업지구 비율
- CHAS : Charles River 인접 여부
- NOX : 질소산화물 농도
- RM : 주택 당 방 개수
- AGE : 1940년 이전에 건설 된 자가 점유 유닛 비율
- DIS : 보스턴 고용센터까지의 가중치 거리
- RAD : 고속도로 접근도 지수
- TAX : 10,000달러 당 재산세
- PTRATIO : 마을별 학생 대 교사 비율
- B : 마을별 흑인 비율
- LSTAT : 마을별 인구 당 저소득층 비율
'''

df = pd.read_csv("./data/boston.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT     y
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# #### 타겟데이터(y) 분리
# <img src="./image/07.png" height="300px" width="300px">

# %%
# X, y 분리
y= df['y'] 
print(y)

X = df.drop('y', axis=1) # axis=1 : 열방향 작업
print(X)
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: y, Length: 506, dtype: float64
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# #### train test split
# <img src="./image/08.png" height="300px" width="300px">

# %%
# 데이터셋 분리
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD    TAX  \
# 308   0.49298   0.0   9.90   0.0  0.544  6.635  82.5  3.3175   4.0  304.0
# 424   8.79212   0.0  18.10   0.0  0.584  5.565  70.6  2.0635  24.0  666.0
# 56    0.02055  85.0   0.74   0.0  0.410  6.383  35.7  9.1876   2.0  313.0
# 257   0.61154  20.0   3.97   0.0  0.647  8.704  86.9  1.8010   5.0  264.0
# 32    1.38799   0.0   8.14   0.0  0.538  5.950  82.0  3.9900   4.0  307.0
# ..        ...   ...    ...   ...    ...    ...   ...     ...   ...    ...
# 294   0.08199   0.0  13.92   0.0  0.437  6.009  42.3  5.5027   4.0  289.0
# 474   8.05579   0.0  18.10   0.0  0.584  5.427  95.4  2.4298  24.0  666.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671   2.0  242.0
# 445  10.67180   0.0  18.10   0.0  0.740  6.459  94.8  1.9879  24.0  666.0
# 225   0.52693   0.0   6.20   0.0  0.504  8.725  83.0  2.8944   8.0  307.0
#
#      PTRATIO       B  LSTAT
# 308     18.4  396.90   4.54
# 424     20.2    3.65  17.16
# 56      17.3  396.90   5.77
# 257     13.0  389.70   5.12
# 32      21.0  232.60  27.71
# ..       ...     ...    ...
# 294     16.0  396.90  10.40
# 474     20.2  352.58  18.14
# 2       17.8  392.83   4.03
# 445     20.2   43.06  23.98
# 225     17.4  382.00   4.63
#
# [379 rows x 13 columns]

# %% [markdown]
# #### 모델생성
# <img src="./image/09.png" height="400px" width="900px">

# %%
# 모델 정의
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %% [markdown]
# #### 모델학습
# <img src="./image/10.png" height="400px" width="900px">

# %%
# 모델 학습
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### 모델 평가
# <img src="./image/11.png" height="400px" width="900px">

# %%
# 모델 예측
pred = model.predict(X_test)

# %%
# 모델 평가
from sklearn.metrics import r2_score

print(f'R2 score: {r2_score(y_test, pred)}')
# Out:
# R2 score: 0.7488990453321489
